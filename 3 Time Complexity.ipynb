# %%
# import symbolic capability to Python
from sympy import *
from sympy.abc import *
from sympy.plotting import plot
from IPython.display import display
# print things all pretty
init_printing()

# %% [markdown]
# # Size of the problem: n

# %%
n = symbols("n", positive=True, real=True)

# %% [markdown]
# # Different Functions f with different Time complexity

# %%
f_constant = 20
f_linear = n * 4 + 10
f_linear2 = 10 * n +1
f_quadratic = 1/4 * n**2 + 1/2*n +1 
f_quadratic2 = 1/8 * n**2

# %% [markdown]
# # Definition of Order of Growth (O) ("Big O")
#
# Order of growth (O) is a set of functions whose asymptotic growth behavior is considered equivalent:
#
# Two functions f(n) and g(n) have the equivalent order of growth if $\displaystyle \lim_{n \rightarrow \infty} \frac{f(n)}{g(n)} = c$ with $c > 0$ and $c < \infty $.
#
#
# f(n) has a higher order of growth than g(n) if
# $\displaystyle \lim_{n \rightarrow \infty} \frac{f(n)}{g(n)} = \infty $.
#
# f(n) has a smaller order of growth than g(n) if $\displaystyle \lim_{n \rightarrow \infty} \frac{f(n)}{g(n)} = 0 $.
#
# $f(n) \in O(g(n))$ if $\displaystyle \lim_{n \rightarrow \infty} \frac{f(n)}{g(n)} = c$ with $c < \infty $.

# %% [markdown]
# # Test Order of Growth with the Sympy limit function

# %%
limit(f_quadratic / f_quadratic2, n, oo)
# Out:
# 2.00000000000000

# %%
limit(f_quadratic / f_linear, n, oo)
# Out:
# ∞

# %%
limit(f_linear2 / f_quadratic2, n, oo)
# Out:
# 0

# %% [markdown]
# # Plotting Time Complexity

# %%
expr_range = (n,0,30)
p = plot(
    f_constant,
    f_linear,
    f_quadratic,
    expr_range,
    show = False,
    legend = True
);

p[0].line_color = 'g'
p[1].line_color = 'b'
p[2].line_color = 'r'



p[0].label = 'constant'
p[1].label = 'linear'
p[2].label = 'quadratic'

p.show()

# %% [markdown]
# # Crossover point

# %%
e1 = Eq(f_quadratic, f_linear)
e1
# Out:
#       2
# 0.25⋅n  + 0.5⋅n + 1 = 4⋅n + 10

# %%
solve(e1, n)
# Out:
# [16.2195444572929]

# %%
solve(e1, n)[0].evalf()
# Out:
# 16.2195444572929

# %% [markdown]
# # Todo

# %% [markdown]
# ### Self-defined funcitons

# %%
# TODO: Define 
# - a logarithmic function
f_logarithmic = ln(n) * 2
# - a log-linear (n log n) function
f_log_linear = n * ln(n) +1
# - a cubic function
f_cubic = 1/2 * n**3
# - an exponential function
f_exponential = 2**n
# - a factorial function
f_factorial = factorial(n)

# %% [markdown]
# ### Plot logarithmic, log-linear and quadratic functions

# %%
p = plot(
    f_logarithmic, 
    f_log_linear,
    f_quadratic,
    expr_range,
    show = False,
    legend = True
);

p[0].line_color = 'g'
p[1].line_color = 'b'
p[2].line_color = 'r'

p[0].label = 'logarithmic'
p[1].label = 'log-linear'
p[2].label = 'quadratic'

p.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/sympy/plotting/experimental_lambdify.py:233: UserWarning: The evaluation of the expression is problematic. We are trying a failback method that may still work. Please report this as a bug.
#   warnings.warn('The evaluation of the expression is'

# %% [markdown]
# ### Plot the relationship of cubic and exponential funcitons with two different ranges

# %%
ranges = ((n,0,10), (n,0,30))
for r in ranges:
    p = plot(
        f_cubic, 
        f_exponential,
        r,
        show = False,
        legend = True
    );

    p[0].line_color = 'g'
    p[1].line_color = 'b'

    p[0].label = 'cubic'
    p[1].label = 'exponential'

    p.show()

# %% [markdown]
# ### Plot the relationship of cubic exponential and factorial funcitons with two different ranges

# %%
for r in ranges:
    p = plot(
        f_exponential, 
        f_factorial,
        r,
        show = False,
        legend = True
    );

    p[0].line_color = 'g'
    p[1].line_color = 'b'

    p[0].label = 'exponential'
    p[1].label = 'factorial'

    p.show()

# %% [markdown]
# ### Test log-log plot with simplest case of logarithmic, linear exponential functions

# %%
f_logarithmic1 = ln(n)
f_linear1 = n
f_exponential1 = 2**n
expr_range = (n,0,4)
p = plot(
    f_logarithmic1,
    f_linear1,
    f_exponential1,
    expr_range,
    show = False,
    legend = True
);

p.xlim = (10**(-1), 10)
p.ylim = (10**(-1), 10)

p[0].line_color = 'g'
p[1].line_color = 'b'
p[2].line_color = 'r'


p[0].label = 'logarithmic'
p[1].label = 'linear'
p[2].label = 'exponential'

p.xscale = 'log'
p.yscale = 'log'

p.show()

# %% [markdown]
# ### Create log-log plot with the factorial, exponential, quadratic, log-linear, and linear function

# %%
# TODO create a log-log plot with your factorial, exponential, quadratic, log-linear, and linear function
expr_range = (n,0,30)
p = plot(
    f_logarithmic,
    f_log_linear,
    f_cubic,
    f_exponential,
    f_factorial,
    expr_range,
    show = False,
    legend = True
);

p.xlim = (10**(-1), 100)
p.ylim = (10**(-2), 10**4)

p[0].line_color = 'g'
p[1].line_color = 'b'
p[2].line_color = 'r'
p[3].line_color = 'y'
p[4].line_color = 'k'


p[0].label = 'logarithmic'
p[1].label = 'log_linear'
p[2].label = 'cubic'
p[3].label = 'exponential'
p[4].label = 'factorial'

p.xscale = 'log'
p.yscale = 'log'

p.show()

# %% [markdown]
# ###  Crossover point for cubic and exponential functions

# %%
# TODO Calculate one crossover point for two functions
e1 = Eq(f_cubic, f_exponential)
e1
# Out:
#      3    n
# 0.5⋅n  = 2

# %%
solve(e1, n)
# Out:
# [2.0, 8.0]

# %%
solve(e1, n)[0].evalf()
# Out:
# 2.00000000000000
